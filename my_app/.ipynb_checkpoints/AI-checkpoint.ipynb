# %%
# !pip install openai
# Out:
# Collecting openai
#   Using cached openai-2.28.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from openai) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from openai) (0.12.0)
# Collecting pydantic<3,>=1.9.0 (from openai)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Requirement already satisfied: sniffio in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from openai) (4.67.1)
# Collecting typing-extensions<5,>=4.11 (from openai)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: idna>=2.8 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from tqdm>4->openai) (0.4.6)
# Using cached openai-2.28.0-py3-none-any.whl (1.1 MB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Installing collected packages: typing-extensions, pydantic, openai
#
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    ---------------------------------------- 3/3 [openai]
#
# Successfully installed openai-2.28.0 pydantic-2.12.5 typing-extensions-4.15.0
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\yeoeun02\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\yeoeun02\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\yeoeun02\AppData\Local\Programs\Python\Python314\Lib\site-packages)

# %%
from openai import OpenAI
client = OpenAI()
resp = client.chat.completions.create(
        model="gpt-5",
        messages=[{"role":"user","content":"이거 하나보내는데 토큰얼마야."}]
    )
print(resp.choices[0].message.content)
# Out:
# 대충 이 문장 하나는 본문 기준으로 약 8토큰 전후야.
# 다만 정확한 값은 쓰는 모델/토크나이저마다 조금씩 달고, 채팅 형식으로 보낼 때는 메시지 메타데이터 때문에 몇 토큰이 더 붙어서 실청구 입력 토큰은 대략 10~15토큰 정도로 볼 수 있어.
#
# 정확히 알고 싶으면 사용하는 모델의 토크나이저로 세면 돼:
# - OpenAI GPT-4o 계열: tiktoken의 o200k_base
# - GPT-4/3.5 계열: tiktoken의 cl100k_base
#
# 예시(Python):
# import tiktoken
# enc = tiktoken.get_encoding("o200k_base")  # 모델에 맞게 변경
# len(enc.encode("이거 하나보내는데 토큰얼마야."))
#
# 모델 알려주면 더 정확히 계산해줄게.

# %%
def ask(prompt, model="gpt-4o-mini", system=None):
        from openai import OpenAI
        client = OpenAI()
        msgs = []
        if system:
            msgs.append({"role":"system","content":system})
        msgs.append({"role":"user","content":prompt})
        r = client.chat.completions.create(model=model, messages=msgs)
        return r.choices[0].message.content

# %%
print(ask("그럼 파이썬에 openai 연결 완료했어 api key도 연결했고 답변들어오는거 까지확인했는데 다음에 뭐하지"))
# Out:
# 훌륭합니다! OpenAI API를 성공적으로 연결했으니 다음 단계로 무엇을 할 수 있는지 몇 가지 아이디어를 제안해드릴게요.
#
# 1. **기본 질문/응답 시스템 만들기**:
#    - 기본적인 질문/응답 챗봇을 만들어서 사용자가 질문을 입력하면 OpenAI API가 답변을 제공하도록 설정해보세요.
#
# 2. **토픽별 정보 검색**:
#    - 특정 주제(예: 기술, 과학, 역사 등)에 대한 정보를 검색하고 요약하는 프로그램을 만들어보세요.
#
# 3. **창작 작업**:
#    - 아이디어가 필요할 때 사용하거나 창작물이 필요할 때 도움을 줄 수 있는 텍스트 생성 도구를 만들어 보세요. 예를 들어, 스토리, 시, 블로그 게시물 등을 생성하는 기능을 추가할 수 있습니다.
#
# 4. **대화형 애플리케이션 개발**:
#    - Flask나 Django와 같은 웹 프레임워크를 사용하여 간단한 웹 애플리케이션을 만들어보고, 사용자가 질문을 입력하고 응답을 받을 수 있는 인터페이스를 구현해보세요.
#
# 5. **자연어 처리(NLP) 기능 추가**:
#    - 텍스트 분석, 감정 분석, 키워드 추출 등의 기능을 추가하여 보다 고도화된 애플리케이션을 만들어 보세요.
#
# 6. **조정 및 튜닝**:
#    - 파라미터(예: max_tokens, temperature 등)를 조정하여 다양한 응답 스타일을 실험해보고, 결과가 어떻게 달라지는지 확인해보세요.
#
# 7. **데이터 수집 및 저장**:
#    - 사용자가 입력한 질문과 API의 응답을 로그로 기록해두고, 이를 후에 분석할 수 있도록 해보세요.
#
# 이 외에도 많은 가능성이 있으니, 흥미 있는 프로젝트나 아이디어를 발전시켜보세요! 필요하면 추가적인 코드나 구현에 대한 질문을 해주시면 도와드리겠습니다.

# %%
from openai import OpenAI
client = OpenAI()

stream = client.responses.create(
    model="gpt-5",
    input=[
        {
            "role": "user",
            "content": "Say 'double bubble bath' ten times fast.",
        },
    ],
    stream=True,
)

for event in stream:
    print(event)
# Out:
# ResponseCreatedEvent(response=Response(id='resp_01f0b478b75d6eb20069b3b1783bec8196aca09bd006accb99', created_at=1773384056.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5-2025-08-07', object='response', output=[], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort='medium', generate_summary=None, summary=None), safety_identifier=None, service_tier='auto', status='in_progress', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=None, user=None, completed_at=None, frequency_penalty=0.0, presence_penalty=0.0, store=True), sequence_number=0, type='response.created')
# ResponseInProgressEvent(response=Response(id='resp_01f0b478b75d6eb20069b3b1783bec8196aca09bd006accb99', created_at=1773384056.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5-2025-08-07', object='response', output=[], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort='medium', generate_summary=None, summary=None), safety_identifier=None, service_tier='auto', status='in_progress', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=None, user=None, completed_at=None, frequency_penalty=0.0, presence_penalty=0.0, store=True), sequence_number=1, type='response.in_progress')
# ResponseOutputItemAddedEvent(item=ResponseReasoningItem(id='rs_01f0b478b75d6eb20069b3b178f0dc81969f9bee49ccdab8df', summary=[], type='reasoning', content=None, encrypted_content=None, status=None), output_index=0, sequence_number=2, type='response.output_item.added')
# ResponseOutputItemDoneEvent(item=ResponseReasoningItem(id='rs_01f0b478b75d6eb20069b3b178f0dc81969f9bee49ccdab8df', summary=[], type='reasoning', content=None, encrypted_content=None, status=None), output_index=0, sequence_number=3, type='response.output_item.done')
# ResponseOutputItemAddedEvent(item=ResponseOutputMessage(id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', content=[], role='assistant', status='in_progress', type='message'), output_index=1, sequence_number=4, type='response.output_item.added')
# ResponseContentPartAddedEvent(content_index=0, item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', output_index=1, part=ResponseOutputText(annotations=[], text='', type='output_text', logprobs=[]), sequence_number=5, type='response.content_part.added')
# ResponseTextDeltaEvent(content_index=0, delta='double', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=6, type='response.output_text.delta', obfuscation='5JuVVW6qoS')
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=7, type='response.output_text.delta', obfuscation='D9mTiAL9R')
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=8, type='response.output_text.delta', obfuscation='Wg2EbEDjgwv')
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=9, type='response.output_text.delta', obfuscation='DSr9cixpi')
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=10, type='response.output_text.delta', obfuscation='o24aRIXr3')
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=11, type='response.output_text.delta', obfuscation='seqOnCrQI25')
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=12, type='response.output_text.delta', obfuscation='1MClxve6A')
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=13, type='response.output_text.delta', obfuscation='KTXhbadSt')
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=14, type='response.output_text.delta', obfuscation='G1Gu3wPxPOm')
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=15, type='response.output_text.delta', obfuscation='AiXbcVhXk')
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=16, type='response.output_text.delta', obfuscation='QZARTKkjf')
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=17, type='response.output_text.delta', obfuscation='CbEXFsKMnm2')
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=18, type='response.output_text.delta', obfuscation='A2qHctQgZ')
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=19, type='response.output_text.delta', obfuscation='5njcDmH7u')
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=20, type='response.output_text.delta', obfuscation='vcpyoqHcmC3')
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=21, type='response.output_text.delta', obfuscation='OCt6zaA0M')
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=22, type='response.output_text.delta', obfuscation='kogIleG0T')
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=23, type='response.output_text.delta', obfuscation='mR3SSqP6K6S')
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=24, type='response.output_text.delta', obfuscation='VmdWpiq5s')
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=25, type='response.output_text.delta', obfuscation='qu4s6F7nr')
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=26, type='response.output_text.delta', obfuscation='csWhlS86UDv')
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=27, type='response.output_text.delta', obfuscation='SbgOhTVfg')
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=28, type='response.output_text.delta', obfuscation='ewMCTxbCn')
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=29, type='response.output_text.delta', obfuscation='nwZ61kABxsb')
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=30, type='response.output_text.delta', obfuscation='ft7lY4RRJ')
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=31, type='response.output_text.delta', obfuscation='7OorDvuHo')
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=32, type='response.output_text.delta', obfuscation='L7U5vAe352p')
# ResponseTextDeltaEvent(content_index=0, delta=' double', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=33, type='response.output_text.delta', obfuscation='bFUEKpvQH')
# ResponseTextDeltaEvent(content_index=0, delta=' bubble', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=34, type='response.output_text.delta', obfuscation='sJ3H2TsVU')
# ResponseTextDeltaEvent(content_index=0, delta=' bath', item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=35, type='response.output_text.delta', obfuscation='PF2xxnZqioM')
# ResponseTextDoneEvent(content_index=0, item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', logprobs=[], output_index=1, sequence_number=36, text='double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath', type='response.output_text.done')
# ResponseContentPartDoneEvent(content_index=0, item_id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', output_index=1, part=ResponseOutputText(annotations=[], text='double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath', type='output_text', logprobs=[]), sequence_number=37, type='response.content_part.done')
# ResponseOutputItemDoneEvent(item=ResponseOutputMessage(id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', content=[ResponseOutputText(annotations=[], text='double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath', type='output_text', logprobs=[])], role='assistant', status='completed', type='message'), output_index=1, sequence_number=38, type='response.output_item.done')
# ResponseCompletedEvent(response=Response(id='resp_01f0b478b75d6eb20069b3b1783bec8196aca09bd006accb99', created_at=1773384056.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5-2025-08-07', object='response', output=[ResponseReasoningItem(id='rs_01f0b478b75d6eb20069b3b178f0dc81969f9bee49ccdab8df', summary=[], type='reasoning', content=None, encrypted_content=None, status=None), ResponseOutputMessage(id='msg_01f0b478b75d6eb20069b3b17f46dc81969e2c5fc7aa497925', content=[ResponseOutputText(annotations=[], text='double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath double bubble bath', type='output_text', logprobs=[])], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort='medium', generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=16, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=340, output_tokens_details=OutputTokensDetails(reasoning_tokens=256), total_tokens=356), user=None, completed_at=1773384063, frequency_penalty=0.0, presence_penalty=0.0, store=True), sequence_number=39, type='response.completed')

# %%
pip install agents
# Out:
# Collecting agents
#   Downloading agents-1.4.0.tar.gz (37 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# INFO: pip is looking at multiple versions of agents to determine which version is compatible with other requirements. This could take a while.
#   Downloading agents-1.3.2.tar.gz (35 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
#   Downloading agents-1.3.1.tar.gz (35 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
#   Downloading agents-1.2.1.tar.gz (31 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
#   Downloading agents-1.2.0.tar.gz (31 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
#   Downloading agents-1.1.0.tar.gz (29 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
#   Downloading agents-1.0.3.tar.gz (30 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
#   Downloading agents-1.0.2.tar.gz (1.4 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# INFO: pip is still looking at multiple versions of agents to determine which version is compatible with other requirements. This could take a while.
#   Downloading agents-1.0.0.tar.gz (1.4 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
#
# The conflict is caused by:
#     agents 1.4.0 depends on tensorflow
#     agents 1.3.2 depends on tensorflow
#     agents 1.3.1 depends on tensorflow
#     agents 1.2.1 depends on tensorflow
#     agents 1.2.0 depends on tensorflow
#     agents 1.1.0 depends on tensorflow
#     agents 1.0.3 depends on tensorflow
#     agents 1.0.2 depends on tensorflow
#     agents 1.0.0 depends on tensorflow
#
# Additionally, some packages in these conflicts have no matching distributions available for your environment:
#     tensorflow
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip to attempt to solve the dependency conflict
#
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Cannot install agents==1.0.0, agents==1.0.2, agents==1.0.3, agents==1.1.0, agents==1.2.0, agents==1.2.1, agents==1.3.1, agents==1.3.2 and agents==1.4.0 because these package versions have conflicting dependencies.
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts

# %%
SYSTEM_PROMPT = """
너는 친절한 한국어 대화형 챗봇이다.
답변은 자연스럽고 이해하기 쉽게 해라.
모르는 것은 추측하지 말고 모른다고 말해라.
"""

previous_response_id = None

print("챗봇 시작! 종료하려면 quit 입력")

while True:
    user_input = input("나: ").strip()
    
    if user_input.lower() in ["quit", "exit", "종료"]:
        print("챗봇을 종료합니다.")
        break

    try:
        response = client.responses.create(
            model="gpt-5.4",
            instructions=SYSTEM_PROMPT,
            input=user_input,
            previous_response_id=previous_response_id
        )

        bot_text = response.output_text
        print(f"챗봇: {bot_text}")

        previous_response_id = response.id

    except Exception as e:
        print("오류 발생:", e)
# Out:
# 챗봇 시작! 종료하려면 quit 입력
# 나:  안녕 챗봇아
# 챗봇: 안녕하세요! 😊
# 무엇을 도와드릴까요?
# 나:  대화형 챗봇이 구축이 됬구나 너 대화 데이터도 저장하니?
# 챗봇: 네, 일반적으로는 **서비스 제공자가 대화 데이터를 저장할 수 있습니다.**
# 다만 **어떻게, 얼마나, 왜 저장되는지는 서비스 정책에 따라 다릅니다.**
#
# 보통은 이런 경우가 많아요:
# - **대화 품질 개선**을 위해 저장
# - **오류 분석 / 악용 방지**를 위해 로그 보관
# - **맞춤형 기능 제공**을 위해 일부 정보 유지
# - 일정 기간 후 **삭제**하거나 **익명화** 처리
#
# 하지만 저는 지금 이 대화 안에서만 문맥을 보고 답하는 것이고,
# **실제로 어떤 데이터가 저장되는지는 이 서비스를 운영하는 시스템 정책을 확인해야 정확합니다.**
#
# 확인할 때는 보통 이런 문서를 보면 돼요:
# - **개인정보처리방침**
# - **이용약관**
# - **데이터 보관 정책**
# - **대화 기록 저장 여부 / 학습 활용 여부 안내**
#
# 원하시면 제가
# **“챗봇 서비스에서 대화 저장 여부를 확인하는 방법”**도 간단히 정리해드릴게요.
# 나:  quit
# 챗봇을 종료합니다.

# %%
pip install streamlit openai
# Out:
# Requirement already satisfied: streamlit in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (1.55.0)
# Requirement already satisfied: openai in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (2.12.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (7.0.5)
# Requirement already satisfied: click<9,>=7.0 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (2.4.3)
# Requirement already satisfied: packaging>=20 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (12.1.1)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (6.33.5)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (23.0.1)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (6.5.4)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.27.1 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.18.0)
# Requirement already satisfied: colorama in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from requests<3,>=2.27->streamlit) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.11.12)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from openai) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: httpcore==1.* in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas openpyxl python-pptx python-docx pypdf pillow python-dotenv
# Out:
# Requirement already satisfied: pandas in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (2.3.3)
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting python-pptx
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting python-docx
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting pypdf
#   Downloading pypdf-6.9.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: pillow in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (12.1.1)
# Requirement already satisfied: python-dotenv in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (1.2.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.3)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting XlsxWriter>=0.5.7 (from python-pptx)
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Collecting lxml>=3.1.0 (from python-pptx)
#   Downloading lxml-6.0.2-cp314-cp314-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from python-pptx) (4.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\yeoeun02\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
# Downloading pypdf-6.9.0-py3-none-any.whl (333 kB)
# Downloading lxml-6.0.2-cp314-cp314-win_amd64.whl (4.1 MB)
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------------------------------------- 4.1/4.1 MB 62.6 MB/s  0:00:00
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: XlsxWriter, pypdf, lxml, et-xmlfile, python-pptx, python-docx, openpyxl
#
#    ---------------------------------------- 0/7 [XlsxWriter]
#    ---------------------------------------- 0/7 [XlsxWriter]
#    ---------------------------------------- 0/7 [XlsxWriter]
#    ---------------------------------------- 0/7 [XlsxWriter]
#    ---------------------------------------- 0/7 [XlsxWriter]
#    ----- ---------------------------------- 1/7 [pypdf]
#    ----- ---------------------------------- 1/7 [pypdf]
#    ----- ---------------------------------- 1/7 [pypdf]
#    ----- ---------------------------------- 1/7 [pypdf]
#    ----- ---------------------------------- 1/7 [pypdf]
#    ----- ---------------------------------- 1/7 [pypdf]
#    ----- ---------------------------------- 1/7 [pypdf]
#    ----- ---------------------------------- 1/7 [pypdf]
#    ----- ---------------------------------- 1/7 [pypdf]
#    ----------- ---------------------------- 2/7 [lxml]
#    ----------- ---------------------------- 2/7 [lxml]
#    ----------- ---------------------------- 2/7 [lxml]
#    ----------- ---------------------------- 2/7 [lxml]
#    ----------------- ---------------------- 3/7 [et-xmlfile]
#    ---------------------- ----------------- 4/7 [python-pptx]
#    ---------------------- ----------------- 4/7 [python-pptx]
#    ---------------------- ----------------- 4/7 [python-pptx]
#    ---------------------- ----------------- 4/7 [python-pptx]
#    ---------------------- ----------------- 4/7 [python-pptx]
#    ---------------------- ----------------- 4/7 [python-pptx]
#    ---------------------- ----------------- 4/7 [python-pptx]
#    ---------------------- ----------------- 4/7 [python-pptx]
#    ---------------------- ----------------- 4/7 [python-pptx]
#    ---------------------- ----------------- 4/7 [python-pptx]
#    ---------------------- ----------------- 4/7 [python-pptx]
#    ---------------------------- ----------- 5/7 [python-docx]
#    ---------------------------- ----------- 5/7 [python-docx]
#    ---------------------------- ----------- 5/7 [python-docx]
#    ---------------------------- ----------- 5/7 [python-docx]
#    ---------------------------- ----------- 5/7 [python-docx]
#    ---------------------------- ----------- 5/7 [python-docx]
#    ---------------------------- ----------- 5/7 [python-docx]
#    ---------------------------- ----------- 5/7 [python-docx]
#    ---------------------------- ----------- 5/7 [python-docx]
#    ---------------------------- ----------- 5/7 [python-docx]
#    ---------------------------------- ----- 6/7 [openpyxl]
#    ---------------------------------- ----- 6/7 [openpyxl]
#    ---------------------------------- ----- 6/7 [openpyxl]
#    ---------------------------------- ----- 6/7 [openpyxl]
#    ---------------------------------- ----- 6/7 [openpyxl]
#    ---------------------------------- ----- 6/7 [openpyxl]
#    ---------------------------------- ----- 6/7 [openpyxl]
#    ---------------------------------- ----- 6/7 [openpyxl]
#    ---------------------------------- ----- 6/7 [openpyxl]
#    ---------------------------------- ----- 6/7 [openpyxl]
#    ---------------------------------- ----- 6/7 [openpyxl]
#    ---------------------------------- ----- 6/7 [openpyxl]
#    ---------------------------------- ----- 6/7 [openpyxl]
#    ---------------------------------- ----- 6/7 [openpyxl]
#    ---------------------------------- ----- 6/7 [openpyxl]
#    ---------------------------------- ----- 6/7 [openpyxl]
#    ---------------------------------- ----- 6/7 [openpyxl]
#    ---------------------------------------- 7/7 [openpyxl]
#
# Successfully installed XlsxWriter-3.2.9 et-xmlfile-2.0.0 lxml-6.0.2 openpyxl-3.1.5 pypdf-6.9.0 python-docx-1.2.0 python-pptx-1.0.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %%writefile app.py
import os
import io
import json
import re
import base64
import hashlib
from datetime import datetime

import pandas as pd
import streamlit as st
from docx import Document
from openai import OpenAI
from pypdf import PdfReader
from pptx import Presentation

# ---------------------------------
# 기본 설정
# ---------------------------------
st.set_page_config(
    page_title="내 AI 챗봇",
    page_icon="🤖",
    layout="wide"
)

st.markdown("""
<style>
.block-container {
    padding-top: 1.5rem;
}
section[data-testid="stSidebar"] {
    width: 320px !important;
}
.chat-title {
    font-size: 2.2rem;
    font-weight: 800;
    margin-bottom: 1rem;
}
</style>
""", unsafe_allow_html=True)

st.markdown('<div class="chat-title">🤖 내 AI 챗봇</div>', unsafe_allow_html=True)

# ---------------------------------
# 경로 / 상수
# ---------------------------------
USERS_FILE = "users.json"
BASE_CHAT_DIR = "chats"
os.makedirs(BASE_CHAT_DIR, exist_ok=True)

# ---------------------------------
# OpenAI
# ---------------------------------
api_key = os.getenv("OPENAI_API_KEY") or st.secrets.get("OPENAI_API_KEY")

if not api_key:
    st.error("OPENAI_API_KEY가 없습니다. 환경변수 또는 Streamlit secrets에 설정하세요.")
    st.stop()

client = OpenAI(api_key=api_key)

# ---------------------------------
# 로그인 관련
# ---------------------------------
def load_users():
    if os.path.exists(USERS_FILE):
        with open(USERS_FILE, "r", encoding="utf-8") as f:
            return json.load(f)
    return []

def hash_password(password: str) -> str:
    return hashlib.sha256(password.encode()).hexdigest()

def verify_login(username: str, password: str) -> bool:
    users = load_users()
    password_hash = hash_password(password)
    for user in users:
        if user["username"] == username and user["password_hash"] == password_hash:
            return True
    return False

def get_user_chat_dir():
    username = st.session_state.get("username")
    user_dir = os.path.join(BASE_CHAT_DIR, username)
    os.makedirs(user_dir, exist_ok=True)
    return user_dir

# ---------------------------------
# 파일 읽기 함수
# ---------------------------------
def read_pdf(file):
    try:
        file.seek(0)
        reader = PdfReader(file)
        text = ""
        for page in reader.pages:
            text += page.extract_text() or ""
        return text.strip()
    except Exception as e:
        return f"[PDF 읽기 실패: {e}]"

def read_excel(file):
    try:
        file.seek(0)
        excel = pd.ExcelFile(file)
        text_parts = []
        previews = []

        for sheet_name in excel.sheet_names:
            df = pd.read_excel(excel, sheet_name=sheet_name)
            previews.append((sheet_name, df.head(20)))
            text_parts.append(f"[시트: {sheet_name}]")
            text_parts.append(df.head(50).to_string(index=False))

        return "\n\n".join(text_parts), previews
    except Exception as e:
        return f"[Excel 읽기 실패: {e}]", []

def read_csv(file):
    try:
        file.seek(0)
        df = pd.read_csv(file)
        return df.head(50).to_string(index=False), df.head(20)
    except Exception:
        try:
            file.seek(0)
            df = pd.read_csv(file, encoding="cp949")
            return df.head(50).to_string(index=False), df.head(20)
        except Exception as e:
            return f"[CSV 읽기 실패: {e}]", None

def read_ppt(file):
    try:
        file.seek(0)
        prs = Presentation(file)
        text = ""
        for i, slide in enumerate(prs.slides, start=1):
            slide_texts = []
            for shape in slide.shapes:
                if hasattr(shape, "text") and shape.text:
                    value = shape.text.strip()
                    if value:
                        slide_texts.append(value)
            text += f"\n[슬라이드 {i}]\n" + "\n".join(slide_texts) + "\n"
        return text.strip()
    except Exception as e:
        return f"[PPT 읽기 실패: {e}]"

def read_docx(file):
    try:
        file.seek(0)
        doc = Document(file)
        return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])
    except Exception as e:
        return f"[DOCX 읽기 실패: {e}]"

def read_txt(file):
    file.seek(0)
    raw = file.getvalue()
    for enc in ("utf-8", "cp949", "euc-kr"):
        try:
            return raw.decode(enc)
        except Exception:
            pass
    return raw.decode("utf-8", errors="ignore")

def image_to_base64(file):
    file.seek(0)
    return base64.b64encode(file.getvalue()).decode()

# ---------------------------------
# 엑셀 변환 / 구조화 데이터 추출
# ---------------------------------
def dataframe_to_excel_bytes(df: pd.DataFrame, sheet_name="result"):
    output = io.BytesIO()
    with pd.ExcelWriter(output, engine="xlsxwriter") as writer:
        df.to_excel(writer, index=False, sheet_name=sheet_name)
    return output.getvalue()

def extract_json_block(text: str):
    if not text:
        return None

    patterns = [
        r"```json\s*(.*?)\s*```",
        r"```[\w]*\s*(\[\s*{.*?}\s*\])\s*```",
        r"```[\w]*\s*(\{\s*.*?\s*\})\s*```",
    ]

    for pattern in patterns:
        m = re.search(pattern, text, re.DOTALL)
        if m:
            candidate = m.group(1).strip()
            try:
                return json.loads(candidate)
            except Exception:
                pass

    stripped = text.strip()
    if stripped.startswith("[") or stripped.startswith("{"):
        try:
            return json.loads(stripped)
        except Exception:
            pass

    return None

def json_to_dataframe(data):
    if isinstance(data, list):
        if len(data) == 0:
            return pd.DataFrame()
        if all(isinstance(x, dict) for x in data):
            return pd.DataFrame(data)
        return pd.DataFrame({"value": data})

    if isinstance(data, dict):
        for value in data.values():
            if isinstance(value, list) and value and all(isinstance(x, dict) for x in value):
                return pd.DataFrame(value)
        return pd.DataFrame([data])

    return None

def parse_markdown_table_to_df(text: str):
    if not text or "|" not in text:
        return None

    lines = [line.strip() for line in text.splitlines() if "|" in line]
    if len(lines) < 2:
        return None

    header_idx = None
    for i in range(len(lines) - 1):
        if re.fullmatch(r"\|?[\s:-|]+\|?", lines[i + 1]):
            header_idx = i
            break

    if header_idx is None:
        return None

    header_line = lines[header_idx]
    data_lines = lines[header_idx + 2:]

    headers = [h.strip() for h in header_line.strip("|").split("|")]
    rows = []

    for line in data_lines:
        cells = [c.strip() for c in line.strip("|").split("|")]
        if len(cells) == len(headers):
            rows.append(cells)

    if not rows:
        return None

    return pd.DataFrame(rows, columns=headers)

def try_build_result_dataframe(full_text: str):
    data = extract_json_block(full_text)
    if data is not None:
        df = json_to_dataframe(data)
        if df is not None and not df.empty:
            return df

    df = parse_markdown_table_to_df(full_text)
    if df is not None and not df.empty:
        return df

    return None

# ---------------------------------
# 대화 저장 함수
# ---------------------------------
def chat_path(chat_id: str) -> str:
    return os.path.join(get_user_chat_dir(), f"{chat_id}.json")

def create_new_chat():
    chat_id = datetime.now().strftime("%Y%m%d_%H%M%S_%f")
    data = {
        "title": "새 대화",
        "messages": [
            {"role": "assistant", "content": "안녕하세요! 무엇을 도와드릴까요?"}
        ]
    }
    with open(chat_path(chat_id), "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)
    return chat_id

def load_chat(chat_id: str):
    path = chat_path(chat_id)
    if os.path.exists(path):
        with open(path, "r", encoding="utf-8") as f:
            return json.load(f)
    return {
        "title": "새 대화",
        "messages": [
            {"role": "assistant", "content": "안녕하세요! 무엇을 도와드릴까요?"}
        ]
    }

def save_chat(chat_id: str, data: dict):
    with open(chat_path(chat_id), "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

def list_chats():
    files = []
    user_dir = get_user_chat_dir()
    for name in os.listdir(user_dir):
        if name.endswith(".json"):
            files.append(name.replace(".json", ""))
    files.sort(reverse=True)

    result = []
    for chat_id in files:
        try:
            data = load_chat(chat_id)
            result.append({
                "id": chat_id,
                "title": data.get("title", "제목 없음")
            })
        except Exception:
            pass
    return result

def delete_chat(chat_id: str):
    path = chat_path(chat_id)
    if os.path.exists(path):
        os.remove(path)

def make_title_from_messages(messages):
    for msg in messages:
        if msg["role"] == "user":
            text = msg["content"].strip().replace("\n", " ")
            return text[:20] if len(text) > 20 else text
    return "새 대화"

# ---------------------------------
# 프롬프트
# ---------------------------------
def build_system_prompt(answer_length: str) -> str:
    if answer_length == "짧게":
        length_rule = "답변은 핵심만 2~3문장으로 간단히 설명한다."
    elif answer_length == "보통":
        length_rule = "답변은 3~6문장 정도로 설명한다."
    else:
        length_rule = "답변은 충분히 자세하게 설명하고, 필요하면 예시와 항목 정리를 포함한다."

    return f"""
너는 친절하고 유능한 한국어 AI 챗봇이다.
항상 한국어로 답변한다.
모르는 내용은 추측하지 말고 불확실하다고 말한다.
사용자가 파일을 첨부한 경우 첨부 내용을 우선 참고한다.
사용자가 이미지(여권, 비자, 신분증, 계약서, 문서 캡처 등)를 첨부하면 OCR 텍스트에 의존하지 말고 이미지 자체를 직접 판독해서 답변한다.

이미지에서 특히 아래 정보가 있으면 정리한다.
- 이름
- 여권번호
- 국적
- 생년월일
- 발급일
- 만료일
- 비자 종류
- 체류기간

생년월일, 발급일, 만료일은 가능하면 YYYY-MM-DD 형태로 정리한다.
확실하지 않은 값은 추정이라고 표시하거나 비워둘 수 있다.
이미지 속 텍스트가 흐리거나 일부 가려져 있으면 보이는 범위 내에서만 답변한다.
사용자가 표, 엑셀, 리스트, 정리본을 요청하면 가능하면 JSON 배열 또는 표 형태로 구조화해서 제공한다.
가능하면 표 형태나 JSON 형태로 정리한다.
{length_rule}
"""

# ---------------------------------
# 세션 초기화
# ---------------------------------
if "logged_in" not in st.session_state:
    st.session_state.logged_in = False

if "username" not in st.session_state:
    st.session_state.username = None

if "uploaded_files_cache" not in st.session_state:
    st.session_state.uploaded_files_cache = []

if "answer_length" not in st.session_state:
    st.session_state.answer_length = "보통"

if "model_name" not in st.session_state:
    st.session_state.model_name = "gpt-4.1-mini"

if "last_result_df" not in st.session_state:
    st.session_state.last_result_df = None

# ---------------------------------
# 로그인 화면
# ---------------------------------
if not st.session_state.logged_in:
    st.subheader("🔐 로그인")

    login_username = st.text_input("아이디")
    login_password = st.text_input("비밀번호", type="password")

    if st.button("로그인", use_container_width=True):
        if verify_login(login_username, login_password):
            st.session_state.logged_in = True
            st.session_state.username = login_username
            st.success("로그인되었습니다.")
            st.rerun()
        else:
            st.error("아이디 또는 비밀번호가 올바르지 않습니다.")

    st.info("users.json에 미리 계정을 등록해두면 됩니다.")
    st.stop()

# ---------------------------------
# 로그인 후 현재 대화 초기화
# ---------------------------------
if "current_chat_id" not in st.session_state:
    chats = list_chats()
    if chats:
        st.session_state.current_chat_id = chats[0]["id"]
    else:
        st.session_state.current_chat_id = create_new_chat()

# ---------------------------------
# 사이드바
# ---------------------------------
with st.sidebar:
    st.write(f"로그인 사용자: **{st.session_state.username}**")

    if st.button("로그아웃", use_container_width=True):
        st.session_state.logged_in = False
        st.session_state.username = None
        st.session_state.uploaded_files_cache = []
        st.session_state.last_result_df = None
        if "current_chat_id" in st.session_state:
            del st.session_state["current_chat_id"]
        st.rerun()

    st.divider()
    st.header("대화")

    if st.button("＋ 새 대화", use_container_width=True):
        st.session_state.current_chat_id = create_new_chat()
        st.session_state.uploaded_files_cache = []
        st.session_state.last_result_df = None
        st.rerun()

    st.divider()

    for chat in list_chats():
        col1, col2 = st.columns([4, 1])

        with col1:
            if st.button(chat["title"], key=f"open_{chat['id']}", use_container_width=True):
                st.session_state.current_chat_id = chat["id"]
                st.session_state.uploaded_files_cache = []
                st.session_state.last_result_df = None
                st.rerun()

        with col2:
            if st.button("🗑", key=f"del_{chat['id']}", use_container_width=True):
                deleting_current = (st.session_state.current_chat_id == chat["id"])
                delete_chat(chat["id"])
                remaining = list_chats()
                if deleting_current:
                    if remaining:
                        st.session_state.current_chat_id = remaining[0]["id"]
                    else:
                        st.session_state.current_chat_id = create_new_chat()
                st.rerun()

    st.divider()
    st.header("답변 설정")

    model_options = ["gpt-4o-mini", "gpt-4.1-mini", "gpt-4.1","gpt-5.4"]
    if st.session_state.model_name not in model_options:
        st.session_state.model_name = "gpt-4.1"

    st.session_state.model_name = st.selectbox(
        "모델",
        model_options,
        index=model_options.index(st.session_state.model_name)
    )

    length_options = ["짧게", "보통", "자세히"]
    if st.session_state.answer_length not in length_options:
        st.session_state.answer_length = "보통"

    st.session_state.answer_length = st.selectbox(
        "답변 길이",
        length_options,
        index=length_options.index(st.session_state.answer_length)
    )

# ---------------------------------
# 현재 대화 로드
# ---------------------------------
current_data = load_chat(st.session_state.current_chat_id)
messages = current_data["messages"]

# ---------------------------------
# 파일 업로드
# ---------------------------------
st.subheader("📎 파일 첨부")

uploaded_files = st.file_uploader(
    "여기에 파일을 드래그하거나 클릭해서 선택하세요",
    type=[
        "pdf", "xlsx", "xls", "csv",
        "pptx", "docx", "txt",
        "png", "jpg", "jpeg", "webp"
    ],
    accept_multiple_files=True,
    key="main_file_uploader"
)

if uploaded_files is not None and len(uploaded_files) > 0:
    st.session_state.uploaded_files_cache = uploaded_files

active_files = st.session_state.uploaded_files_cache

file_context = ""
image_inputs = []

if active_files:
    st.success(f"{len(active_files)}개 파일 업로드됨")

    for f in active_files:
        ext = f.name.split(".")[-1].lower()
        st.write("첨부됨:", f.name)

        try:
            if ext == "pdf":
                text = read_pdf(f)
                file_context += f"\n\n[PDF: {f.name}]\n{text}"

            elif ext in ["xlsx", "xls"]:
                excel_text, previews = read_excel(f)
                file_context += f"\n\n[EXCEL: {f.name}]\n{excel_text}"
                for sheet_name, df in previews:
                    with st.expander(f"미리보기: {f.name} / {sheet_name}", expanded=False):
                        st.dataframe(df, use_container_width=True)

            elif ext == "csv":
                csv_text, preview_df = read_csv(f)
                file_context += f"\n\n[CSV: {f.name}]\n{csv_text}"
                if preview_df is not None:
                    with st.expander(f"미리보기: {f.name}", expanded=False):
                        st.dataframe(preview_df, use_container_width=True)

            elif ext == "pptx":
                text = read_ppt(f)
                file_context += f"\n\n[PPTX: {f.name}]\n{text}"

            elif ext == "docx":
                text = read_docx(f)
                file_context += f"\n\n[DOCX: {f.name}]\n{text}"

            elif ext == "txt":
                text = read_txt(f)
                file_context += f"\n\n[TXT: {f.name}]\n{text}"

            elif ext in ["png", "jpg", "jpeg", "webp"]:
                with st.expander(f"이미지 미리보기: {f.name}", expanded=False):
                    st.image(f, caption=f"{f.name} 원본", use_container_width=True)

                file_context += f"""
[이미지 파일: {f.name}]
이 이미지는 사용자가 첨부한 원본 이미지입니다.
OCR 전처리 텍스트는 제공하지 않으니, 필요한 경우 이미지 자체를 직접 분석하세요.
여권, 비자, 신분증, 문서 이미지, 캡처 화면일 수 있으므로
이름, 여권번호, 국적, 생년월일, 발급일, 만료일, 비자 종류, 체류기간 등의 정보가 보이면 정리하세요.
"""

                image_inputs.append({
                    "type": "input_image",
                    "image_url": f"data:{f.type};base64,{image_to_base64(f)}"
                })

        except Exception as e:
            st.error(f"{f.name} 처리 중 오류: {e}")

    if st.button("첨부 파일 비우기"):
        st.session_state.uploaded_files_cache = []
        st.rerun()
else:
    st.info("업로드된 파일 없음")

with st.expander("첨부 데이터 확인", expanded=False):
    st.write("file_context 길이:", len(file_context))
    st.write("image_inputs 개수:", len(image_inputs))

# ---------------------------------
# 대화 출력
# ---------------------------------
for msg in messages:
    with st.chat_message(msg["role"]):
        st.write(msg["content"])

# ---------------------------------
# 사용자 입력
# ---------------------------------
user_input = st.chat_input("메시지를 입력하세요")

if user_input:
    messages.append({"role": "user", "content": user_input})

    if current_data.get("title") in ["새 대화", "제목 없음"]:
        current_data["title"] = make_title_from_messages(messages)

    current_data["messages"] = messages
    save_chat(st.session_state.current_chat_id, current_data)

    with st.chat_message("user"):
        st.write(user_input)

    with st.chat_message("assistant"):
        placeholder = st.empty()
        full_text = ""

        try:
            history_for_model = []
            for msg in messages[:-1]:
                history_for_model.append({
                    "role": msg["role"],
                    "content": msg["content"]
                })

            user_content = [
                {
                    "type": "input_text",
                    "text": f"""사용자 질문:
{user_input}

첨부 파일 내용:
{file_context if file_context else "첨부된 파일 없음"}
"""
                }
            ]

            if image_inputs:
                user_content.extend(image_inputs)

            stream = client.responses.create(
                model=st.session_state.model_name,
                input=[
                    {"role": "system", "content": build_system_prompt(st.session_state.answer_length)},
                    *history_for_model,
                    {"role": "user", "content": user_content}
                ],
                stream=True
            )

            for event in stream:
                if event.type == "response.output_text.delta":
                    full_text += event.delta
                    placeholder.markdown(full_text + "▌")
                elif event.type == "response.completed":
                    break

            placeholder.markdown(full_text)

        except Exception as e:
            full_text = f"오류가 발생했습니다: {e}"
            placeholder.error(full_text)

        messages.append({"role": "assistant", "content": full_text})
        current_data["messages"] = messages
        save_chat(st.session_state.current_chat_id, current_data)

        result_df = try_build_result_dataframe(full_text)
        st.session_state.last_result_df = result_df

        if result_df is not None and not result_df.empty:
            st.subheader("📊 AI 결과 표")
            st.dataframe(result_df, use_container_width=True)

            result_excel = dataframe_to_excel_bytes(result_df, sheet_name="ai_result")
            st.download_button(
                label="📥 AI 결과 Excel 다운로드",
                data=result_excel,
                file_name="ai_result.xlsx",
                mime="application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
                key=f"download_ai_excel_{st.session_state.current_chat_id}"
            )
# Out:
# Overwriting app.py

# %%
# !streamlit run app.py
# Out:
# ^C
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://10.16.14.184:8501
# 2026-03-17 09:55:38.096 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:38.099 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:38.305 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:38.308 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:38.573 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:38.574 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:43.494 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:43.496 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:43.692 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:43.696 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:43.927 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:43.929 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:43.949 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:46.853 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:46.856 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:47.068 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:47.070 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:47.316 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:47.318 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:47.322 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:49.910 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:49.912 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:50.101 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:50.104 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:50.345 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:50.347 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:55:50.351 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:06.876 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:06.879 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:07.210 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:07.214 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:07.614 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:07.618 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:07.624 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:08.625 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:08.629 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:08.937 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:08.940 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:09.325 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:09.329 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:09.335 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:11.032 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:11.035 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:11.257 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:11.260 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:11.559 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:11.563 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:11.566 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:45.605 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:45.608 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:45.998 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:46.001 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:46.451 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:46.454 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:46.461 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:51.156 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:51.160 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:51.391 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:51.393 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:57:51.397 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:58:04.714 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:58:04.716 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:58:04.951 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:58:04.953 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:58:28.956 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:58:28.960 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:58:29.294 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:58:29.296 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:58:29.304 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:58:30.377 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:58:30.380 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:58:30.644 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:58:30.647 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-03-17 09:58:30.654 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.

# %%
# !streamlit run app.py --server.address 0.0.0.0 --server.port 8501
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://10.16.14.184:8501

# %%
# %%writefile create_user.py
import json
import hashlib
import os

USERS_FILE = "users.json"


def hash_password(password):
    return hashlib.sha256(password.encode()).hexdigest()


def load_users():
    if os.path.exists(USERS_FILE):
        with open(USERS_FILE, "r", encoding="utf-8") as f:
            return json.load(f)
    return []


def save_users(users):
    with open(USERS_FILE, "w", encoding="utf-8") as f:
        json.dump(users, f, ensure_ascii=False, indent=2)


def create_user(username, password):
    users = load_users()

    # 이미 있는 계정인지 확인
    for user in users:
        if user["username"] == username:
            print("이미 존재하는 사용자입니다.")
            return

    new_user = {
        "username": username,
        "password_hash": hash_password(password)
    }

    users.append(new_user)
    save_users(users)

    print("사용자 생성 완료:", username)


if __name__ == "__main__":
    username = input("아이디 입력: ")
    password = input("비밀번호 입력: ")

    create_user(username, password)
# Out:
# Writing create_user.py

# %%
# !create_user.py
# Out:
# ^C

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\yeoeun02

# %%
pip uninstall openai pydantic typing-extensions -y
# Out:
# Found existing installation: openai 2.28.0
# Uninstalling openai-2.28.0:
#   Successfully uninstalled openai-2.28.0
# Found existing installation: pydantic 2.12.5
# Uninstalling pydantic-2.12.5:
#   Successfully uninstalled pydantic-2.12.5
# Found existing installation: typing_extensions 4.15.0
# Uninstalling typing_extensions-4.15.0:
#   Successfully uninstalled typing_extensions-4.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip cache purge
# Out:
# Files removed: 18 (2.1 MB)
# Directories removed: 0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openai==2.28.0 pydantic==2.12.5 typing-extensions==4.15.0
# Out:
# Collecting openai==2.28.0
#   Downloading openai-2.28.0-py3-none-any.whl.metadata (29 kB)
# Collecting pydantic==2.12.5
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting typing-extensions==4.15.0
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from openai==2.28.0) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from openai==2.28.0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from openai==2.28.0) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from openai==2.28.0) (0.13.0)
# Requirement already satisfied: sniffio in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from openai==2.28.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from openai==2.28.0) (4.67.3)
# Requirement already satisfied: annotated-types>=0.6.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic==2.12.5) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic==2.12.5) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic==2.12.5) (0.4.2)
# Requirement already satisfied: idna>=2.8 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anyio<5,>=3.5.0->openai==2.28.0) (3.11)
# Requirement already satisfied: certifi in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->openai==2.28.0) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->openai==2.28.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==2.28.0) (0.16.0)
# Requirement already satisfied: colorama in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from tqdm>4->openai==2.28.0) (0.4.6)
# Downloading openai-2.28.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 10.1 MB/s  0:00:00
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Installing collected packages: typing-extensions, pydantic, openai
#
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    ---------------------------------------- 3/3 [openai]
#
# Successfully installed openai-2.28.0 pydantic-2.12.5 typing-extensions-4.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show openai
# Out:
# Name: openai
# Version: 2.28.0
# Summary: The official Python library for the openai API
# Home-page: https://github.com/openai/openai-python
# Author:
# Author-email: OpenAI <support@openai.com>
# License: Apache-2.0
# Location: C:\Users\yeoeun02\AppData\Local\Programs\Python\Python314\Lib\site-packages
# Requires: anyio, distro, httpx, jiter, pydantic, sniffio, tqdm, typing-extensions
# Required-by:
# Note: you may need to restart the kernel to use updated packages.
